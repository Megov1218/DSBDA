# %%
import pandas as pd
import numpy as np

df=pd.read_csv("/home/ubuntu/Downloads/hr_dataset.csv")
df
# Out:
#     EmployeeID  Age  MonthlyIncome Attrition     BusinessTravel
# 0            1   55           5189       Yes  Travel_Frequently
# 1            2   23           7974       Yes  Travel_Frequently
# 2            3   28           4119       Yes      Travel_Rarely
# 3            4   28           5216       Yes      Travel_Rarely
# 4            5   33           7805        No      Travel_Rarely
# 5            6   51           5997        No  Travel_Frequently
# 6            7   60           7618        No      Travel_Rarely
# 7            8   35           7114        No      Travel_Rarely
# 8            9   51           7191       Yes  Travel_Frequently
# 9           10   60           7370       Yes         Non_Travel
# 10          11   33           5854        No  Travel_Frequently
# 11          12   38           4016        No  Travel_Frequently
# 12          13   55           4074        No         Non_Travel
# 13          14   22           5963        No      Travel_Rarely
# 14          15   34           5775       Yes      Travel_Rarely
# 15          16   48           3680        No         Non_Travel
# 16          17   24           3382       Yes         Non_Travel
# 17          18   51           6862        No  Travel_Frequently
# 18          19   30           3055       Yes         Non_Travel
# 19          20   33           5603       Yes  Travel_Frequently
# 20          21   51           5487       Yes         Non_Travel
# 21          22   26           6270        No      Travel_Rarely
# 22          23   56           4656        No  Travel_Frequently
# 23          24   42           3562        No  Travel_Frequently
# 24          25   48           3197        No         Non_Travel
# 25          26   38           7526       Yes      Travel_Rarely
# 26          27   46           3047        No         Non_Travel
# 27          28   26           4788       Yes      Travel_Rarely
# 28          29   55           3574       Yes      Travel_Rarely
# 29          30   43           3240        No  Travel_Frequently

# %%
print("The mean of monthly income is :",df.loc[:,"MonthlyIncome"].mean())
print("The mean of age is :",df.loc[:,"Age"].mean())
# Out:
# The mean of monthly income is : 5306.8
# The mean of age is : 40.766666666666666

# %%
print("The median of monthly income is :",df.loc[:,"MonthlyIncome"].median())
print("The median of age is :",df.loc[:,"Age"].median())
# Out:
# The median of monthly income is : 5351.5
# The median of age is : 40.0

# %%
print("The mode of monthly income is :",df.loc[:,"MonthlyIncome"].mode())
print("The mode of age is :",df.loc[:,"Age"].mode())
# Out:
# The mode of monthly income is : 0     3047
# 1     3055
# 2     3197
# 3     3240
# 4     3382
# 5     3562
# 6     3574
# 7     3680
# 8     4016
# 9     4074
# 10    4119
# 11    4656
# 12    4788
# 13    5189
# 14    5216
# 15    5487
# 16    5603
# 17    5775
# 18    5854
# 19    5963
# 20    5997
# 21    6270
# 22    6862
# 23    7114
# 24    7191
# 25    7370
# 26    7526
# 27    7618
# 28    7805
# 29    7974
# Name: MonthlyIncome, dtype: int64
# The mode of age is : 0    51
# Name: Age, dtype: int64

# %%
print("The standard deviation of monthly income is :",df.loc[:,"MonthlyIncome"].std())
print("The standard deviation of age is :",df.loc[:,"Age"].std())
# Out:
# The standard deviation of monthly income is : 1620.948730283255
# The standard deviation of age is : 12.090701281202193

# %%
array1 = np.array(df['MonthlyIncome'])
array2=np.array(df["Age"])
print("Income",array1)
print("Age array",array2)
# Out:
# Income [5189 7974 4119 5216 7805 5997 7618 7114 7191 7370 5854 4016 4074 5963
#  5775 3680 3382 6862 3055 5603 5487 6270 4656 3562 3197 7526 3047 4788
#  3574 3240]
# Age array [55 23 28 28 33 51 60 35 51 60 33 38 55 22 34 48 24 51 30 33 51 26 56 42
#  48 38 46 26 55 43]

# %%
print("Maximum income among the employees is :",max(array1))
print("Minimum income among the employees is :",min(array1))
print("Maximum age among the employees is :",max(array2))
print("Minimum age among the employees is :",min(array2))
# Out:
# Maximum income among the employees is : 7974
# Minimum income among the employees is : 3047
# Maximum age among the employees is : 60
# Minimum age among the employees is : 22

# %%
df.head()
df["BusinessTravel"].replace({"Travel_Rarely":1, "Travel_Frequently":0}, inplace=True)
df["Attrition"].replace({ "Yes":1, "No":0}, inplace=True)
df.head()
# Out:
# /tmp/ipykernel_6880/3523162895.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["BusinessTravel"].replace({"Travel_Rarely":1, "Travel_Frequently":0}, inplace=True)
# /tmp/ipykernel_6880/3523162895.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Attrition"].replace({ "Yes":1, "No":0}, inplace=True)
# /tmp/ipykernel_6880/3523162895.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["Attrition"].replace({ "Yes":1, "No":0}, inplace=True)
#    EmployeeID  Age  MonthlyIncome  Attrition BusinessTravel
# 0           1   55           5189          1              0
# 1           2   23           7974          1              0
# 2           3   28           4119          1              1
# 3           4   28           5216          1              1
# 4           5   33           7805          0              1

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.distplot(x=df['Age'],bins = 10)
# Out:
# /tmp/ipykernel_6880/1441614680.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df['Age'],bins = 10)
# <Axes: ylabel='Density'>
